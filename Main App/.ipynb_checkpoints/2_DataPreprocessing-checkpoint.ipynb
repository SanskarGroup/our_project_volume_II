# %%
# !pip install gdown
# !pip install prettytable
#from tqdm import tqdm

# %%
#data pre processing using google drive clink link url


input_file = "Temp/FetchedUrlGoogleDrive.txt" 
output_file = "Temp/Formatted_urls.txt"

with open(input_file, "r") as f:
    urls = [line.strip() for line in f if line.strip()]  # Remove empty lines

# Format the URLs into a proper Python list
formatted_urls = ",\n".join(f'    "{url}"' for url in urls)

# Save to a file or print
with open(output_file, "w") as f:
    f.write(f"urls = [\n{formatted_urls}\n]")

print("✅ Formatted URLs saved to:", output_file)
# Out:
# ✅ Formatted URLs saved to: Temp/Formatted_urls.txt

# %%
print("Reading the txt file")

f = open("Temp/Formatted_urls.txt", "r")

print(f.read())
# Out:
# Reading the txt file
# urls = [
#
# ]

# %%
import gdown
import re
import os
import requests
from tqdm import tqdm

def extract_file_id(url):
    match = re.search(r'id=([a-zA-Z0-9_-]+)', url)
    return match.group(1) if match else None

def get_filename_from_headers(url):
    response = requests.get(url, stream=True, allow_redirects=True)
    if 'Content-Disposition' in response.headers:
        content_disp = response.headers['Content-Disposition']
        filename_match = re.search(r'filename\*?=(?:UTF-8\'\')?"?([^";]+)', content_disp)
        if filename_match:
            return filename_match.group(1)
    return None

def load_urls_from_file(file_path="formatted_urls.txt"):
    urls = []
    with open(file_path, "r") as f:
        for line in f:
            line = line.strip().strip('"')
            if line.startswith("http"):
                urls.append(line.split("&")[0])
    return urls

def download_files(urls, output_folder='Temp/Inputimg'):
    if not os.path.exists(output_folder):
        os.makedirs(output_folder)
    
    total_files = len(urls)
    with tqdm(total=total_files, desc="Downloading Files", unit="file") as pbar:
        for url in urls:
            file_id = extract_file_id(url)
            if file_id:
                gdrive_url = f'https://drive.google.com/uc?id={file_id}&export=download'
                filename = get_filename_from_headers(gdrive_url)
                if not filename:
                    filename = f"{file_id}.unknown"
                    print(f"⚠️ Failed to retrieve name for file {file_id}. Using default name.")
                output_path = os.path.join(output_folder, filename)
                gdown.download(gdrive_url, output_path, quiet=True, use_cookies=True)
            else:
                print(f"❌ Invalid URL: {url}")
            pbar.update(1)  # Update progress bar

def clear_file_contents(file_paths):
    """Clears the contents of the specified files without deleting the files themselves."""
    for file_path in file_paths:
        try:
            with open(file_path, 'w') as file:
                file.truncate(0)  # Clear the file contents
            print(f"✅ Cleared contents of {file_path}")
        except Exception as e:
            print(f"❌ Error clearing {file_path}: {e}")

if __name__ == "__main__":
    urls = load_urls_from_file("Temp/Formatted_urls.txt")
    print(f"✅ Loaded {len(urls)} URLs from file.")
    download_files(urls)
    print("✅ All contents downloaded")
    print("Clearing the text contents in temp folder!")
    files_to_clear = ["Temp/Formatted_urls.txt", "Temp/FetchedUrlGoogleDrive.txt"]
    clear_file_contents(files_to_clear)
# Out:
# ✅ Loaded 0 URLs from file.
# Downloading Files: 0file [00:00, ?file/s]
# ✅ All contents downloaded
# Clearing the text contents in temp folder!
# ✅ Cleared contents of Temp/Formatted_urls.txt
# ✅ Cleared contents of Temp/FetchedUrlGoogleDrive.txt

# %%
#channel alpha 1.5 & dialatin (5, 5)

import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((5, 5), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-085931691_073512_SOTQEGKTQE.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-085931719_597521_JVPGYKQDYW.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-085931745_849900_ELLPLCQKWB.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-085931763_247242_TPWLZOUQQM.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-085931786_452791_NWHMLQBHFD.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-085931812_923870_JCUJSWBCVC.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-085931832_518402_SUJFMWIHPB.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-085931861_667875_MQCKIDUECS.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-085931882_681366_SIXNEXJKYH.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-085931905_418091_MOFCIEFMEK.png
# Processing complete. All enhanced images have been saved.

# %%
# !pip install prettytable
# !pip install pillow
#!pip install prettytable

# %%
#channel alpha 1.5 & dialatin (10, 10)


import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((10, 10), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-085938716_344316_XOWVBGEFER.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-085938732_691851_CIIGYTFLHZ.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-085938755_158047_UUTJPCYNAF.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-085938762_673124_FXDDSUPYEJ.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-085938777_168964_OWDDWEMNAQ.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-085938790_855541_GDCDLWXWDQ.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-085938800_005967_GSRPKBSSBF.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-085938814_590544_WCBZAXTLZA.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-085938825_138824_TIHIRDLJCT.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-085938836_880359_HXXATSCRTK.png
# Processing complete. All enhanced images have been saved.

# %%
#channel alpha 1.5 & dialatin (15, 15)


import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((15, 15), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-085945783_925418_RAQBNCGBPB.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-085945817_408312_UVTVGIYNMP.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-085945845_669975_WQDXBCMBNQ.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-085945858_405483_ZQQKORKDLB.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-085945876_852054_YAZTJEPJTS.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-085945892_895817_OFCMRENJRX.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-085945903_242899_NPQUVWLTST.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-085945917_312435_KMGXBVDCMN.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-085945929_359258_KTBEQIBWVN.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-085945943_760440_ZHVDJSRAQB.png
# Processing complete. All enhanced images have been saved.

# %%
#channel alpha 1.5 & dialatin (20,20)

import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((20, 20), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-085951061_645515_HLGNKFQIPS.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-085951080_075530_ODAKDHVYNH.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-085951104_064186_ZPMXLIFBUB.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-085951114_201775_DTDVCJRZWF.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-085951128_718419_CHGPZIGKYL.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-085951139_438381_YILXEWAJKD.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-085951143_357902_WMCOARAIBT.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-085951164_548194_OPRDSSWAGK.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-085951175_407186_GRNYNSFWUD.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-085951191_909650_HSEVYHZLGA.png
# Processing complete. All enhanced images have been saved.

# %%
#channel alpha 1.5 & dialatin (25, 25)


import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((25, 25), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-090008629_217353_EFDLLICXIR.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-090008650_796422_TNQWPAFPVK.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-090008674_397299_XBURBQEFIQ.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-090008682_909448_ZJPHLYFUJF.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-090008695_642888_BFCTNJUHVY.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-090008716_576856_LVJGCXWVEF.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-090008728_451497_DRKGKXWBUW.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-090008745_538895_HUZVZMLPBH.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-090008758_629616_EZHDVUCNVF.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-090008773_610684_OCNEMVNWGQ.png
# Processing complete. All enhanced images have been saved.

# %%
#channel alpha 1.5 & dialatin (30, 30)


import cv2
import matplotlib.pyplot as plt
import os
import numpy as np
import random
import string
from datetime import datetime

input_folder = 'Temp/Inputimg'
output_folder = 'Temp/Outputimg'

os.makedirs(output_folder, exist_ok=True)

image_counter = 0  # Folder numbering starting from 0
processed_images = []  # List to store processed images for grid display


def generate_random_name(folder_number):
    # Get current time in the format DDMMYYYY-HHMMSSMS
    timestamp = datetime.now().strftime("%d%m%Y-%H%M%S%f")[:-3]
    # Generate 6 random digits
    random_digits = ''.join(random.choices(string.digits, k=6))
    # Generate 10 random uppercase letters
    random_letters = ''.join(random.choices(string.ascii_uppercase, k=10))
    # Construct the final file name
    return f"{folder_number}_{timestamp}_{random_digits}_{random_letters}.png"


for filename in os.listdir(input_folder):
    if filename.lower().endswith(('.png', '.jpg', '.jpeg')):
        image_path = os.path.join(input_folder, filename)
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
        if image is None:
            print(f"Error: Image not found or could not be loaded at path {image_path}")
            continue
        inverted_image = cv2.bitwise_not(image)

        # Applying thresholding to ensure the background is black
        _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

        # Enhancing contrast and brightness
        alpha = 1.5  # Increase contrast
        beta = 0     # No extra brightness change
        enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

        # Apply dilation to make the text bolder
        kernel = np.ones((30, 30), np.uint8)
        dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

        # Resize to 128x128 pixels
        resized_image = cv2.resize(dilated_image, (128, 128))

        # Generate the unique image name
        output_filename = generate_random_name(image_counter)
        output_path = os.path.join(output_folder, output_filename)

        # Save the processed image
        cv2.imwrite(output_path, resized_image)
        print(f"Enhanced image saved at: {output_path}")

        # Add the resized image to the list for grid display
        processed_images.append(resized_image)

        # Increment the folder counter for naming
        image_counter += 1

# Display all images in a grid
if processed_images:
    num_images = len(processed_images)
    grid_size = int(np.ceil(np.sqrt(num_images)))  # Calculate grid dimensions

    fig, axs = plt.subplots(grid_size, grid_size, figsize=(10, 10))
    axs = axs.flatten()  # Flatten the grid to easily access each subplot

    for i, img in enumerate(processed_images):
        axs[i].imshow(img, cmap='gray')
        axs[i].axis('off')
        axs[i].set_title(f"Image {i + 1}")

    # Hide empty subplots
    for j in range(len(processed_images), len(axs)):
        axs[j].axis('off')

    plt.tight_layout()
    plt.show()
else:
    print("No images to display.")

print("Processing complete. All enhanced images have been saved.")
# Out:
# Enhanced image saved at: Temp/Outputimg\0_21022025-090013490_378703_OHPUDZQVGT.png
# Enhanced image saved at: Temp/Outputimg\1_21022025-090013509_711421_EGFRPLIXOA.png
# Enhanced image saved at: Temp/Outputimg\2_21022025-090013558_435668_IHJTUQAVAV.png
# Enhanced image saved at: Temp/Outputimg\3_21022025-090013566_055135_QSSSFHJFAH.png
# Enhanced image saved at: Temp/Outputimg\4_21022025-090013583_269052_VDSTKJJQFZ.png
# Enhanced image saved at: Temp/Outputimg\5_21022025-090013599_018191_OSLBYFTSBO.png
# Enhanced image saved at: Temp/Outputimg\6_21022025-090013611_402690_PXNDTYOYQM.png
# Enhanced image saved at: Temp/Outputimg\7_21022025-090013632_390705_HLGXWYFXYU.png
# Enhanced image saved at: Temp/Outputimg\8_21022025-090013646_908628_AKNKWZQPGI.png
# Enhanced image saved at: Temp/Outputimg\9_21022025-090013661_866797_RNHCLFDKBB.png
# Processing complete. All enhanced images have been saved.

# %%
import os
import shutil

def delete_folder_contents(folder_name="Temp/Inputimg"):
    """Deletes all files and subfolders inside the specified folder."""
    if not os.path.exists(folder_name):
        print(f"❌ Folder '{folder_name}' does not exist.")
        return

    for item in os.listdir(folder_name):
        item_path = os.path.join(folder_name, item)
        
        try:
            if os.path.isfile(item_path) or os.path.islink(item_path):
                os.remove(item_path)  # Delete file or symbolic link
                print(f"🗑️ Deleted file: {item}")
            elif os.path.isdir(item_path):
                shutil.rmtree(item_path)  # Delete folder
                print(f"📂 Deleted folder: {item}")
        except Exception as e:
            print(f"⚠️ Error deleting {item}: {e}")

    print(f"✅ All contents of '{folder_name}' have been deleted.")

if __name__ == "__main__":
    delete_folder_contents()
# Out:
# 🗑️ Deleted file: 20250201_234819.jpg
# 🗑️ Deleted file: 20250201_234830.jpg
# 🗑️ Deleted file: 20250201_234837.jpg
# 🗑️ Deleted file: 20250201_234842.jpg
# 🗑️ Deleted file: 20250201_234850.jpg
# 🗑️ Deleted file: 20250201_234855.jpg
# 🗑️ Deleted file: 20250201_234904.jpg
# 🗑️ Deleted file: 20250201_234910.jpg
# 🗑️ Deleted file: 20250201_234914.jpg
# 🗑️ Deleted file: 20250201_234925.jpg
# ✅ All contents of 'Temp/Inputimg' have been deleted.

# %%
import os
import time
from prettytable import PrettyTable
from PIL import Image

# Set up the table
table = PrettyTable()
table.field_names = ["File Name", "Folder Name", "Size (KB)", "Dimensions (WxH)", "Creation Time"]
total_images = 0
total_size = 0
total_width = 0
total_height = 0

folders = input("Enter folder names separated by commas: ").split(',')
for folder_name in folders:
    folder_name = folder_name.strip()
    if not os.path.exists(folder_name):
        print(f"Folder '{folder_name}' does not exist. Skipping...")
        continue
    png_files = [f for f in os.listdir(folder_name) if f.lower().endswith('.png')]
    for file_name in png_files:
        file_path = os.path.join(folder_name, file_name)
        creation_time = time.ctime(os.path.getctime(file_path))
        file_size = os.path.getsize(file_path) / 1024
        with Image.open(file_path) as img:
            width, height = img.size
        table.add_row([file_name, folder_name, f"{file_size:.2f} KB", f"{width}x{height}", creation_time])
        
        # Accumulate for mean calculation
        total_images += 1
        total_size += file_size
        total_width += width
        total_height += height

# Display table
if total_images > 0:
    # Calculate the mean width and height
    mean_width = total_width / total_images
    mean_height = total_height / total_images

    print("\nSummary:")
    print(f"Total Images: {total_images}")
    print(f"Total Size: {total_size:.2f} KB")
    print(f"Mean Width: {mean_width:.2f}")
    print(f"Mean Height: {mean_height:.2f}")
    print("\n")
    print(table)
    
else:
    print("No .png images found in the provided folders.")
# Out:
# Enter folder names separated by commas:  Temp/Outputimg
# Summary:
# Total Images: 60
# Total Size: 36.66 KB
# Mean Width: 128.00
# Mean Height: 128.00
#
#
# +--------------------------------------------+----------------+-----------+------------------+--------------------------+
# |                 File Name                  |  Folder Name   | Size (KB) | Dimensions (WxH) |      Creation Time       |
# +--------------------------------------------+----------------+-----------+------------------+--------------------------+
# | 0_21022025-085931691_073512_SOTQEGKTQE.png | Temp/Outputimg |  0.55 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 0_21022025-085938716_344316_XOWVBGEFER.png | Temp/Outputimg |  0.49 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 0_21022025-085945783_925418_RAQBNCGBPB.png | Temp/Outputimg |  0.49 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 0_21022025-085951061_645515_HLGNKFQIPS.png | Temp/Outputimg |  0.50 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 0_21022025-090008629_217353_EFDLLICXIR.png | Temp/Outputimg |  0.49 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 0_21022025-090013490_378703_OHPUDZQVGT.png | Temp/Outputimg |  0.48 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 1_21022025-085931719_597521_JVPGYKQDYW.png | Temp/Outputimg |  0.47 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 1_21022025-085938732_691851_CIIGYTFLHZ.png | Temp/Outputimg |  0.51 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 1_21022025-085945817_408312_UVTVGIYNMP.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 1_21022025-085951080_075530_ODAKDHVYNH.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 1_21022025-090008650_796422_TNQWPAFPVK.png | Temp/Outputimg |  0.57 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 1_21022025-090013509_711421_EGFRPLIXOA.png | Temp/Outputimg |  0.56 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 2_21022025-085931745_849900_ELLPLCQKWB.png | Temp/Outputimg |  0.60 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 2_21022025-085938755_158047_UUTJPCYNAF.png | Temp/Outputimg |  0.64 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 2_21022025-085945845_669975_WQDXBCMBNQ.png | Temp/Outputimg |  0.60 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 2_21022025-085951104_064186_ZPMXLIFBUB.png | Temp/Outputimg |  0.63 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 2_21022025-090008674_397299_XBURBQEFIQ.png | Temp/Outputimg |  0.59 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 2_21022025-090013558_435668_IHJTUQAVAV.png | Temp/Outputimg |  0.61 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 3_21022025-085931763_247242_TPWLZOUQQM.png | Temp/Outputimg |  0.67 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 3_21022025-085938762_673124_FXDDSUPYEJ.png | Temp/Outputimg |  0.73 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 3_21022025-085945858_405483_ZQQKORKDLB.png | Temp/Outputimg |  0.74 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 3_21022025-085951114_201775_DTDVCJRZWF.png | Temp/Outputimg |  0.79 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 3_21022025-090008682_909448_ZJPHLYFUJF.png | Temp/Outputimg |  0.80 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 3_21022025-090013566_055135_QSSSFHJFAH.png | Temp/Outputimg |  0.81 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 4_21022025-085931786_452791_NWHMLQBHFD.png | Temp/Outputimg |  0.70 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 4_21022025-085938777_168964_OWDDWEMNAQ.png | Temp/Outputimg |  0.65 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 4_21022025-085945876_852054_YAZTJEPJTS.png | Temp/Outputimg |  0.65 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 4_21022025-085951128_718419_CHGPZIGKYL.png | Temp/Outputimg |  0.67 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 4_21022025-090008695_642888_BFCTNJUHVY.png | Temp/Outputimg |  0.64 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 4_21022025-090013583_269052_VDSTKJJQFZ.png | Temp/Outputimg |  0.68 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 5_21022025-085931812_923870_JCUJSWBCVC.png | Temp/Outputimg |  0.78 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 5_21022025-085938790_855541_GDCDLWXWDQ.png | Temp/Outputimg |  0.72 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 5_21022025-085945892_895817_OFCMRENJRX.png | Temp/Outputimg |  0.71 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 5_21022025-085951139_438381_YILXEWAJKD.png | Temp/Outputimg |  0.68 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 5_21022025-090008716_576856_LVJGCXWVEF.png | Temp/Outputimg |  0.69 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 5_21022025-090013599_018191_OSLBYFTSBO.png | Temp/Outputimg |  0.71 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 6_21022025-085931832_518402_SUJFMWIHPB.png | Temp/Outputimg |  0.97 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 6_21022025-085938800_005967_GSRPKBSSBF.png | Temp/Outputimg |  0.85 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 6_21022025-085945903_242899_NPQUVWLTST.png | Temp/Outputimg |  0.81 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 6_21022025-085951143_357902_WMCOARAIBT.png | Temp/Outputimg |  0.85 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 6_21022025-090008728_451497_DRKGKXWBUW.png | Temp/Outputimg |  0.82 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 6_21022025-090013611_402690_PXNDTYOYQM.png | Temp/Outputimg |  0.84 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 7_21022025-085931861_667875_MQCKIDUECS.png | Temp/Outputimg |  0.56 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 7_21022025-085938814_590544_WCBZAXTLZA.png | Temp/Outputimg |  0.52 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 7_21022025-085945917_312435_KMGXBVDCMN.png | Temp/Outputimg |  0.53 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 7_21022025-085951164_548194_OPRDSSWAGK.png | Temp/Outputimg |  0.51 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 7_21022025-090008745_538895_HUZVZMLPBH.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 7_21022025-090013632_390705_HLGXWYFXYU.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 8_21022025-085931882_681366_SIXNEXJKYH.png | Temp/Outputimg |  0.60 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 8_21022025-085938825_138824_TIHIRDLJCT.png | Temp/Outputimg |  0.55 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 8_21022025-085945929_359258_KTBEQIBWVN.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 8_21022025-085951175_407186_GRNYNSFWUD.png | Temp/Outputimg |  0.53 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 8_21022025-090008758_629616_EZHDVUCNVF.png | Temp/Outputimg |  0.53 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 8_21022025-090013646_908628_AKNKWZQPGI.png | Temp/Outputimg |  0.54 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# | 9_21022025-085931905_418091_MOFCIEFMEK.png | Temp/Outputimg |  0.40 KB  |     128x128      | Fri Feb 21 08:59:31 2025 |
# | 9_21022025-085938836_880359_HXXATSCRTK.png | Temp/Outputimg |  0.40 KB  |     128x128      | Fri Feb 21 08:59:38 2025 |
# | 9_21022025-085945943_760440_ZHVDJSRAQB.png | Temp/Outputimg |  0.40 KB  |     128x128      | Fri Feb 21 08:59:45 2025 |
# | 9_21022025-085951191_909650_HSEVYHZLGA.png | Temp/Outputimg |  0.39 KB  |     128x128      | Fri Feb 21 08:59:51 2025 |
# | 9_21022025-090008773_610684_OCNEMVNWGQ.png | Temp/Outputimg |  0.40 KB  |     128x128      | Fri Feb 21 09:00:08 2025 |
# | 9_21022025-090013661_866797_RNHCLFDKBB.png | Temp/Outputimg |  0.37 KB  |     128x128      | Fri Feb 21 09:00:13 2025 |
# +--------------------------------------------+----------------+-----------+------------------+--------------------------+

# %%
import cv2
# !pip install opencv-python
# Load the image in grayscale
image = cv2.imread('img/00.jpg', cv2.IMREAD_GRAYSCALE)

inverted_image = cv2.bitwise_not(image)
resized_image = cv2.resize(inverted_image, (28, 28))
cv2.imshow('Inverted Image', resized_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[11], line 8
#       6 inverted_image = cv2.bitwise_not(image)
#       7 resized_image = cv2.resize(inverted_image, (28, 28))
# ----> 8 cv2.imshow('Inverted Image', resized_image)
#       9 cv2.waitKey(0)
#      10 cv2.destroyAllWindows()
#
# error: OpenCV(4.10.0) D:\a\opencv-python\opencv-python\opencv\modules\highgui\src\window.cpp:1301: error: (-2:Unspecified error) The function is not implemented. Rebuild the library with Windows, GTK+ 2.x or Cocoa support. If you are on Ubuntu or Debian, install libgtk2.0-dev and pkg-config, then re-run cmake or configure script in function 'cvShowImage'

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\sansk\Desktop\our_project_volume_II\Handwritten-digit-detection\Custom-datasets\Image-correction

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image in grayscale
image_path = 'img/00.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print(f"Error: Image not found at path {image_path}")
else:
    # Invert the image (black background, white digits)
    inverted_image = cv2.bitwise_not(image)

    # Resize to 28x28 pixels (MNIST style)
    resized_image = cv2.resize(inverted_image, (1024, 1024))

    # Display the image using Matplotlib
    plt.imshow(resized_image, cmap='gray')
    plt.title('Inverted Image')
    plt.axis('off')
    plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
import os

# Load the image in grayscale
image_path = 'img/00.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print(f"Error: Image not found at path {image_path}")
else:
    # Invert the image (black background, white digits)
    inverted_image = cv2.bitwise_not(image)

    # Enhance contrast and brightness: make text whiter and background darker
    # Increase brightness and contrast by scaling pixel values
    alpha = 1.0  # Contrast control (1.0-3.0)
    beta = 50    # Brightness control (0-100)
    enhanced_image = cv2.convertScaleAbs(inverted_image, alpha=alpha, beta=beta)

    # Resize to 1024x1024 pixels
    resized_image = cv2.resize(enhanced_image, (128, 128))

    # Create a folder if it doesn't exist
    output_folder = 'output_images'
    os.makedirs(output_folder, exist_ok=True)

    # Save the edited image
    output_path = os.path.join(output_folder, 'enhanced_edited_image.jpg')
    cv2.imwrite(output_path, resized_image)
    print(f"Enhanced image saved at: {output_path}")

    # Display the image using Matplotlib
    plt.imshow(resized_image, cmap='gray')
    plt.title('Inverted and Enhanced Image')
    plt.axis('off')
    plt.show()
# Out:
# Enhanced image saved at: output_images\enhanced_edited_image.jpg

# %%
import cv2
import matplotlib.pyplot as plt
import os
import numpy as np

# Load the image in grayscale
image_path = 'img/00.jpg'
image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if the image is loaded successfully
if image is None:
    print(f"Error: Image not found at path {image_path}")
else:
    # Invert the image (black background, white digits)
    inverted_image = cv2.bitwise_not(image)

    # Apply thresholding to ensure the background is black
    _, thresholded_image = cv2.threshold(inverted_image, 200, 255, cv2.THRESH_BINARY)

    # Enhance contrast and brightness: make text whiter and background darker
    # Increase brightness and contrast by scaling pixel values
    alpha = 1.5  # Increase contrast
    beta = 0     # No extra brightness change (keep background black)
    enhanced_image = cv2.convertScaleAbs(thresholded_image, alpha=alpha, beta=beta)

    # Apply dilation to make the text bolder (more prominent)
    kernel = np.ones((5, 5), np.uint8)  # Use a larger kernel to make text bolder
    dilated_image = cv2.dilate(enhanced_image, kernel, iterations=1)

    # Resize to 128x128 pixels
    resized_image = cv2.resize(dilated_image, (128, 128))

    # Create a folder if it doesn't exist
    output_folder = 'output_images'
    os.makedirs(output_folder, exist_ok=True)

    # Save the edited image
    output_path = os.path.join(output_folder, 'enhanced_edited_image.jpg')
    cv2.imwrite(output_path, resized_image)
    print(f"Enhanced image saved at: {output_path}")

    # Display the image using Matplotlib
    plt.imshow(resized_image, cmap='gray')
    plt.title('Inverted and Enhanced Image')
    plt.axis('off')
    plt.show()
# Out:
# Enhanced image saved at: output_images\enhanced_edited_image.jpg
